# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sc
import seaborn as sns
import sklearn.metrics as skm
import statsmodels as stm

# %% [markdown]
# # Introducción

# %% [markdown]
# # Datos a Analizar

# %% [markdown]
# ## Demanda

# %%
demanda_DP = pd.read_excel('./Data para Proyecciones/Demanda entregada a DP.xlsx', sheet_name='DEMANDA', usecols='A:I' )
demanda_DP = demanda_DP.drop(columns=['MAL ANTISHOCK', 'MAL COMUNES', 'Market Share antishock', 'Market Share común'])
demanda_DP
demanda_DP.head()
# Out:
#      Periodo  Demanda guantes antishock de De Pascale S.A.  \
# 0 2015-01-01                                           596
# 1 2015-02-01                                           790
# 2 2015-03-01                                          1085
# 3 2015-04-01                                           950
# 4 2015-05-01                                          1623
#
#    Demanda guantes comunes De Pascale S.A.  \
# 0                                   136805
# 1                                   128005
# 2                                   126338
# 3                                   101284
# 4                                   116033
#
#    Demanda guantes antishock a nivel nacional  \
# 0                                 1508.860759
# 1                                 1987.421384
# 2                                 2712.500000
# 3                                 2360.248447
# 4                                 4007.407407
#
#    Demanda guantes comunes a nivel nacional
# 0                                    273610
# 1                                    256010
# 2                                    252676
# 3                                    202568
# 4                                    232066

# %%
demanda_DP.reset_index(inplace=True)
demanda_DP.rename(columns={'index':'t'}, inplace=True)
demanda_DP.head()
# Out:
#    t    Periodo  Demanda guantes antishock de De Pascale S.A.  \
# 0  0 2015-01-01                                           596
# 1  1 2015-02-01                                           790
# 2  2 2015-03-01                                          1085
# 3  3 2015-04-01                                           950
# 4  4 2015-05-01                                          1623
#
#    Demanda guantes comunes De Pascale S.A.  \
# 0                                   136805
# 1                                   128005
# 2                                   126338
# 3                                   101284
# 4                                   116033
#
#    Demanda guantes antishock a nivel nacional  \
# 0                                 1508.860759
# 1                                 1987.421384
# 2                                 2712.500000
# 3                                 2360.248447
# 4                                 4007.407407
#
#    Demanda guantes comunes a nivel nacional
# 0                                    273610
# 1                                    256010
# 2                                    252676
# 3                                    202568
# 4                                    232066

# %%
demanda_DP.columns
# Out:
# Index(['t', 'Periodo', 'Demanda guantes antishock de De Pascale S.A.',
#        'Demanda guantes comunes De Pascale S.A.',
#        'Demanda guantes antishock a nivel nacional',
#        'Demanda guantes comunes a nivel nacional', 'demanda_total_guantes'],
#       dtype='object')

# %%
demanda_DP[['Demanda guantes antishock de De Pascale S.A.',
       'Demanda guantes comunes De Pascale S.A.',
       'Demanda guantes antishock a nivel nacional',
       'Demanda guantes comunes a nivel nacional', 'demanda_total_guantes']] = demanda_DP[['Demanda guantes antishock de De Pascale S.A.',
       'Demanda guantes comunes De Pascale S.A.',
       'Demanda guantes antishock a nivel nacional',
       'Demanda guantes comunes a nivel nacional', 'demanda_total_guantes']].astype(int)

# %%
demanda_DP['demanda_total_guantes'] = demanda_DP['Demanda guantes antishock a nivel nacional'].astype(int) + demanda_DP['Demanda guantes comunes a nivel nacional'].astype(int)
demanda_DP.head(3)
# Out:
#    t    Periodo  Demanda guantes antishock de De Pascale S.A.  \
# 0  0 2015-01-01                                           596
# 1  1 2015-02-01                                           790
# 2  2 2015-03-01                                          1085
#
#    Demanda guantes comunes De Pascale S.A.  \
# 0                                   136805
# 1                                   128005
# 2                                   126338
#
#    Demanda guantes antishock a nivel nacional  \
# 0                                        1508
# 1                                        1987
# 2                                        2712
#
#    Demanda guantes comunes a nivel nacional  demanda_total_guantes
# 0                                    273610                 275118
# 1                                    256010                 257997
# 2                                    252676                 255388

# %%
demanda_DP.plot(x='Periodo', y='demanda_total_guantes')
plt.ylim([50e3, 300e3])
# Out:
# (50000.0, 300000.0)

# %% [markdown]
# ## EMAE de Industria de la Construccion

# %%
dataset = pd.read_excel('./Data para Proyecciones/Dataset_Proyecciones.xlsx')
dataset.head()
# Out:
#    Demanda de guantes      ITCRM  EMAE Manufactura (t -1)  EMAE Manufactura  \
# 0       275118.860759  79.543955               133.862326        118.272738
# 1       257997.421384  78.841323               118.272738        116.838170
# 2       255388.500000  78.487223               116.838170        134.927216
# 3       204928.248447  77.783166               134.927216        137.381394
# 4       236073.407407  77.087749               137.381394        139.361062
#
#    EMAE Construccion (t-1)  EMAE Construccion  Produccion Oil m3 Argentina  \
# 0               139.964452         146.689712                 2.524610e+06
# 1               146.689712         147.782989                 2.262535e+06
# 2               147.782989         151.920156                 2.518664e+06
# 3               151.920156         151.984589                 2.445076e+06
# 4               151.984589         153.409565                 2.536572e+06
#
#    Produccion Oil m3 Patagonia  Precio Brent (t-1)  Precio Brent (y - 1)  \
# 0                 2.387218e+06           62.335000            108.117727
# 1                 2.142219e+06           47.759500            108.900526
# 2                 2.384975e+06           58.095500            107.480952
# 3                 2.315147e+06           55.885455            107.755238
# 4                 2.406750e+06           59.524286            109.539091
#
#    Precio Brent  EMAE Mineria (t-1)  EMAE Mineria  \
# 0     47.759500           94.773137     95.146670
# 1     58.095500           95.146670     88.288470
# 2     55.885455           88.288470     97.375158
# 3     59.524286           97.375158     93.843158
# 4     64.075000           93.843158    100.678522
#
#    Produccion Gas Mm3 Argentina  Produccion Gas Mm3 Patagonia  \
# 0                  3.595407e+06                  2.908825e+06
# 1                  3.229374e+06                  2.628789e+06
# 2                  3.612211e+06                  2.936375e+06
# 3                  3.515646e+06                  2.818163e+06
# 4                  3.669902e+06                  2.945839e+06
#
#    PBI Valor Agregado  Juicios Notificados  Juicios Sin Resolver  \
# 0        4.274443e+06                  111                 66075
# 1        4.274443e+06                 9096                 68487
# 2        4.274443e+06                10341                 71465
# 3        5.016966e+06                10074                 74450
# 4        5.016966e+06                 9827                 77244
#
#    Juicios con Sentencia  Juicios sin Sentencia    Año mes
# 0                     69                     42 2015-01-01
# 1                   6642                   2452 2015-02-01
# 2                   7335                   3008 2015-03-01
# 3                   7043                   3030 2015-04-01
# 4                   6985                   2843 2015-05-01

# %%
dataset.plot(x='Año mes', y='Demanda de guantes')

# %%
dataset.loc[dataset['Año mes'] >= '2018-01-01'].plot(x='Año mes', y='Demanda de guantes')

# %% [markdown]
# # Regresión
#
# Quiero identificar variables que expliquen la demanda

# %%
dataset = pd.read_excel('./Data para Proyecciones/Dataset_Proyecciones.xlsx')
dataset.head()
# Out:
#    Demanda de guantes      ITCRM  EMAE Manufactura (t -1)  EMAE Manufactura  \
# 0       275118.860759  79.543955               133.862326        118.272738
# 1       257997.421384  78.841323               118.272738        116.838170
# 2       255388.500000  78.487223               116.838170        134.927216
# 3       204928.248447  77.783166               134.927216        137.381394
# 4       236073.407407  77.087749               137.381394        139.361062
#
#    EMAE Construccion (t-1)  EMAE Construccion  Produccion Oil m3 Argentina  \
# 0               139.964452         146.689712                 2.524610e+06
# 1               146.689712         147.782989                 2.262535e+06
# 2               147.782989         151.920156                 2.518664e+06
# 3               151.920156         151.984589                 2.445076e+06
# 4               151.984589         153.409565                 2.536572e+06
#
#    Produccion Oil m3 Patagonia  Precio Brent (t-1)  Precio Brent (y - 1)  \
# 0                 2.387218e+06           62.335000            108.117727
# 1                 2.142219e+06           47.759500            108.900526
# 2                 2.384975e+06           58.095500            107.480952
# 3                 2.315147e+06           55.885455            107.755238
# 4                 2.406750e+06           59.524286            109.539091
#
#    Precio Brent  EMAE Mineria (t-1)  EMAE Mineria  \
# 0     47.759500           94.773137     95.146670
# 1     58.095500           95.146670     88.288470
# 2     55.885455           88.288470     97.375158
# 3     59.524286           97.375158     93.843158
# 4     64.075000           93.843158    100.678522
#
#    Produccion Gas Mm3 Argentina  Produccion Gas Mm3 Patagonia  \
# 0                  3.595407e+06                  2.908825e+06
# 1                  3.229374e+06                  2.628789e+06
# 2                  3.612211e+06                  2.936375e+06
# 3                  3.515646e+06                  2.818163e+06
# 4                  3.669902e+06                  2.945839e+06
#
#    PBI Valor Agregado  Juicios Notificados  Juicios Sin Resolver  \
# 0        4.274443e+06                  111                 66075
# 1        4.274443e+06                 9096                 68487
# 2        4.274443e+06                10341                 71465
# 3        5.016966e+06                10074                 74450
# 4        5.016966e+06                 9827                 77244
#
#    Juicios con Sentencia  Juicios sin Sentencia    Año mes
# 0                     69                     42 2015-01-01
# 1                   6642                   2452 2015-02-01
# 2                   7335                   3008 2015-03-01
# 3                   7043                   3030 2015-04-01
# 4                   6985                   2843 2015-05-01

# %%
# dataset = dataset.loc[dataset['Año mes'] > '2018-01-01']

# %%
dataset.drop(columns=['Año mes'], inplace=True)

# %%
plt.figure(figsize=(15,15))
sns.heatmap(dataset.corr(), vmin=-1, vmax=1, annot=True)

# %%
import statsmodels.api as stm
from statsmodels.formula.api import ols

# %%
dataset.columns
# Out:
# Index(['Demanda de guantes', 'ITCRM', 'EMAE Manufactura (t -1)',
#        'EMAE Manufactura', 'EMAE Construccion (t-1)', 'EMAE Construccion',
#        'Produccion Oil m3 Argentina', 'Produccion Oil m3 Patagonia',
#        'Precio Brent (t-1)', 'Precio Brent (y - 1)', 'Precio Brent',
#        'EMAE Mineria (t-1)', 'EMAE Mineria', 'Produccion Gas Mm3 Argentina',
#        'Produccion Gas Mm3 Patagonia', 'PBI Valor Agregado',
#        'Juicios Notificados', 'Juicios Sin Resolver', 'Juicios con Sentencia',
#        'Juicios sin Sentencia'],
#       dtype='object')

# %%
results.pvalues
# Out:
# const                          0.601403
# PBI Valor Agregado             0.003450
# Produccion Oil m3 Patagonia    0.000713
# Juicios Notificados            0.000143
# Juicios con Sentencia          0.000143
# Juicios sin Sentencia          0.000144
# Produccion Oil m3 Argentina    0.000591
# Precio Brent                   0.000752
# dtype: float64

# %%
#Backward Elimination
X = dataset.drop(columns=['Demanda de guantes']).astype(float)
y = dataset['Demanda de guantes']

cols = list(X.columns)
np.random.shuffle(cols)
pmax = 1
while (len(cols)>0):
    p= []
    X_1 = X[cols]
    X_1 = stm.add_constant(X_1)
    model = stm.OLS(y,X_1).fit()
    p = pd.Series(model.pvalues.values[1:],index = cols)      
    pmax = max(p)
    feature_with_p_max = p.idxmax()
    if(pmax>0.05):
        cols.remove(feature_with_p_max)
    else:
        break
selected_features_BE = cols
print(selected_features_BE)
# Out:
# ['Precio Brent (t-1)', 'Juicios Notificados', 'Produccion Oil m3 Patagonia', 'Produccion Oil m3 Argentina', 'Juicios sin Sentencia', 'PBI Valor Agregado', 'Juicios con Sentencia']

# %%
X_sf = dataset[selected_features_BE]
# X_sf = dataset[['Juicios Notificados', 'Juicios con Sentencia', 'Juicios sin Sentencia']]
y = dataset['Demanda de guantes']

X_sf = stm.add_constant(X_sf)
Y = dataset['Demanda de guantes']

model = stm.OLS(Y,X_sf, hasconst=True)

results = model.fit()
results.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                              Results: Ordinary least squares
# =========================================================================================
# Model:                      OLS                      Adj. R-squared:           0.352
# Dependent Variable:         Demanda de guantes       AIC:                      1419.1634
# Date:                       2020-04-26 10:40         BIC:                      1435.9182
# No. Observations:           60                       Log-Likelihood:           -701.58
# Df Model:                   7                        F-statistic:              5.572
# Df Residuals:               52                       Prob (F-statistic):       7.96e-05
# R-squared:                  0.429                    Scale:                    9.6852e+08
# -----------------------------------------------------------------------------------------
#                                Coef.     Std.Err.     t    P>|t|     [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                       -81894.5583 90364.7678 -0.9063 0.3690 -263224.7307 99435.6140
# Precio Brent (t-1)           -1592.6805   511.9384 -3.1111 0.0030   -2619.9600  -565.4010
# Juicios Notificados          -3909.5294   966.0145 -4.0471 0.0002   -5847.9794 -1971.0794
# Produccion Oil m3 Patagonia     -3.8022     1.0037 -3.7880 0.0004      -5.8163    -1.7880
# Produccion Oil m3 Argentina      3.7533     0.9734  3.8560 0.0003       1.8001     5.7065
# Juicios sin Sentencia         3910.6816   966.6335  4.0457 0.0002    1970.9895  5850.3736
# PBI Valor Agregado               0.0114     0.0039  2.8928 0.0056       0.0035     0.0193
# Juicios con Sentencia         3906.9405   965.7997  4.0453 0.0002    1968.9216  5844.9593
# -----------------------------------------------------------------------------------------
# Omnibus:                      3.048              Durbin-Watson:                 1.891
# Prob(Omnibus):                0.218              Jarque-Bera (JB):              1.727
# Skew:                         0.113              Prob(JB):                      0.422
# Kurtosis:                     2.200              Condition No.:                 265075760
# =========================================================================================
# * The condition number is large (3e+08). This might indicate             strong
# multicollinearity or other numerical problems.
# """

# %%
selected_features_BE
# Out:
# ['Precio Brent (t-1)',
#  'Juicios Notificados',
#  'Produccion Oil m3 Patagonia',
#  'Produccion Oil m3 Argentina',
#  'Juicios sin Sentencia',
#  'PBI Valor Agregado',
#  'Juicios con Sentencia']

# %% [markdown]
# ## Desfasando un año

# %%
dataset = pd.read_excel('./Data para Proyecciones/Dataset_Proyecciones.xlsx')
dataset.head()
# Out:
#    Demanda de guantes      ITCRM  EMAE Manufactura (t -1)  EMAE Manufactura  \
# 0       275118.860759  79.543955               133.862326        118.272738
# 1       257997.421384  78.841323               118.272738        116.838170
# 2       255388.500000  78.487223               116.838170        134.927216
# 3       204928.248447  77.783166               134.927216        137.381394
# 4       236073.407407  77.087749               137.381394        139.361062
#
#    EMAE Construccion (t-1)  EMAE Construccion  Produccion Oil m3 Argentina  \
# 0               139.964452         146.689712                 2.524610e+06
# 1               146.689712         147.782989                 2.262535e+06
# 2               147.782989         151.920156                 2.518664e+06
# 3               151.920156         151.984589                 2.445076e+06
# 4               151.984589         153.409565                 2.536572e+06
#
#    Produccion Oil m3 Patagonia  Precio Brent (t-1)  Precio Brent (y - 1)  \
# 0                 2.387218e+06           62.335000            108.117727
# 1                 2.142219e+06           47.759500            108.900526
# 2                 2.384975e+06           58.095500            107.480952
# 3                 2.315147e+06           55.885455            107.755238
# 4                 2.406750e+06           59.524286            109.539091
#
#    Precio Brent  EMAE Mineria (t-1)  EMAE Mineria  \
# 0     47.759500           94.773137     95.146670
# 1     58.095500           95.146670     88.288470
# 2     55.885455           88.288470     97.375158
# 3     59.524286           97.375158     93.843158
# 4     64.075000           93.843158    100.678522
#
#    Produccion Gas Mm3 Argentina  Produccion Gas Mm3 Patagonia  \
# 0                  3.595407e+06                  2.908825e+06
# 1                  3.229374e+06                  2.628789e+06
# 2                  3.612211e+06                  2.936375e+06
# 3                  3.515646e+06                  2.818163e+06
# 4                  3.669902e+06                  2.945839e+06
#
#    PBI Valor Agregado  Juicios Notificados  Juicios Sin Resolver  \
# 0        4.274443e+06                  111                 66075
# 1        4.274443e+06                 9096                 68487
# 2        4.274443e+06                10341                 71465
# 3        5.016966e+06                10074                 74450
# 4        5.016966e+06                 9827                 77244
#
#    Juicios con Sentencia  Juicios sin Sentencia    Año mes
# 0                     69                     42 2015-01-01
# 1                   6642                   2452 2015-02-01
# 2                   7335                   3008 2015-03-01
# 3                   7043                   3030 2015-04-01
# 4                   6985                   2843 2015-05-01

# %%
dataset['Año mes'] = pd.to_datetime(dataset['Año mes'])
dataset.set_index('Año mes', drop=True, inplace=True)
dataset.head()
# Out:
#             Demanda de guantes      ITCRM  EMAE Manufactura (t -1)  \
# Año mes
# 2015-01-01       275118.860759  79.543955               133.862326
# 2015-02-01       257997.421384  78.841323               118.272738
# 2015-03-01       255388.500000  78.487223               116.838170
# 2015-04-01       204928.248447  77.783166               134.927216
# 2015-05-01       236073.407407  77.087749               137.381394
#
#             EMAE Manufactura  EMAE Construccion (t-1)  EMAE Construccion  \
# Año mes
# 2015-01-01        118.272738               139.964452         146.689712
# 2015-02-01        116.838170               146.689712         147.782989
# 2015-03-01        134.927216               147.782989         151.920156
# 2015-04-01        137.381394               151.920156         151.984589
# 2015-05-01        139.361062               151.984589         153.409565
#
#             Produccion Oil m3 Argentina  Produccion Oil m3 Patagonia  \
# Año mes
# 2015-01-01                 2.524610e+06                 2.387218e+06
# 2015-02-01                 2.262535e+06                 2.142219e+06
# 2015-03-01                 2.518664e+06                 2.384975e+06
# 2015-04-01                 2.445076e+06                 2.315147e+06
# 2015-05-01                 2.536572e+06                 2.406750e+06
#
#             Precio Brent (t-1)  Precio Brent (y - 1)  Precio Brent  \
# Año mes
# 2015-01-01           62.335000            108.117727     47.759500
# 2015-02-01           47.759500            108.900526     58.095500
# 2015-03-01           58.095500            107.480952     55.885455
# 2015-04-01           55.885455            107.755238     59.524286
# 2015-05-01           59.524286            109.539091     64.075000
#
#             EMAE Mineria (t-1)  EMAE Mineria  Produccion Gas Mm3 Argentina  \
# Año mes
# 2015-01-01           94.773137     95.146670                  3.595407e+06
# 2015-02-01           95.146670     88.288470                  3.229374e+06
# 2015-03-01           88.288470     97.375158                  3.612211e+06
# 2015-04-01           97.375158     93.843158                  3.515646e+06
# 2015-05-01           93.843158    100.678522                  3.669902e+06
#
#             Produccion Gas Mm3 Patagonia  PBI Valor Agregado  \
# Año mes
# 2015-01-01                  2.908825e+06        4.274443e+06
# 2015-02-01                  2.628789e+06        4.274443e+06
# 2015-03-01                  2.936375e+06        4.274443e+06
# 2015-04-01                  2.818163e+06        5.016966e+06
# 2015-05-01                  2.945839e+06        5.016966e+06
#
#             Juicios Notificados  Juicios Sin Resolver  Juicios con Sentencia  \
# Año mes
# 2015-01-01                  111                 66075                     69
# 2015-02-01                 9096                 68487                   6642
# 2015-03-01                10341                 71465                   7335
# 2015-04-01                10074                 74450                   7043
# 2015-05-01                 9827                 77244                   6985
#
#             Juicios sin Sentencia
# Año mes
# 2015-01-01                     42
# 2015-02-01                   2452
# 2015-03-01                   3008
# 2015-04-01                   3030
# 2015-05-01                   2843

# %%
dataset.columns.tolist()
# Out:
# ['Demanda de guantes',
#  'ITCRM',
#  'EMAE Manufactura (t -1)',
#  'EMAE Manufactura',
#  'EMAE Construccion (t-1)',
#  'EMAE Construccion',
#  'Produccion Oil m3 Argentina',
#  'Produccion Oil m3 Patagonia',
#  'Precio Brent (t-1)',
#  'Precio Brent (y - 1)',
#  'Precio Brent',
#  'EMAE Mineria (t-1)',
#  'EMAE Mineria',
#  'Produccion Gas Mm3 Argentina',
#  'Produccion Gas Mm3 Patagonia',
#  'PBI Valor Agregado',
#  'Juicios Notificados',
#  'Juicios Sin Resolver',
#  'Juicios con Sentencia',
#  'Juicios sin Sentencia']

# %%
drop_cols = [col for col in dataset.columns if ('(' in col ) or ('Patagonia' in col)]
dataset.drop(columns=drop_cols, inplace=True)

# %%
dataset.drop(columns=[
    'Juicios Sin Resolver',
 'Juicios con Sentencia',
 'Juicios sin Sentencia',
     'EMAE Construccion',
#  'Produccion Oil m3 Argentina',
#     'Produccion Gas Mm3 Argentina',
], inplace=True)

# %%
# dataset['EMAE Manufactura (y-1)'] = 

for col in dataset.drop(columns=['Demanda de guantes', 'ITCRM']):
    
    
    new_name = f'{col} (y-1)'
    
    dataset[new_name] = dataset[col].shift(periods=12).fillna(0)
    
    new_name_2 = f'{col} squared'
    
    dataset[new_name_2] = dataset[col].apply(lambda x: x**2)
    
dataset.head()
# Out:
#             Demanda de guantes      ITCRM  EMAE Manufactura  \
# Año mes
# 2015-01-01       275118.860759  79.543955        118.272738
# 2015-02-01       257997.421384  78.841323        116.838170
# 2015-03-01       255388.500000  78.487223        134.927216
# 2015-04-01       204928.248447  77.783166        137.381394
# 2015-05-01       236073.407407  77.087749        139.361062
#
#             Produccion Oil m3 Argentina  Precio Brent  EMAE Mineria  \
# Año mes
# 2015-01-01                 2.524610e+06     47.759500     95.146670
# 2015-02-01                 2.262535e+06     58.095500     88.288470
# 2015-03-01                 2.518664e+06     55.885455     97.375158
# 2015-04-01                 2.445076e+06     59.524286     93.843158
# 2015-05-01                 2.536572e+06     64.075000    100.678522
#
#             Produccion Gas Mm3 Argentina  PBI Valor Agregado  \
# Año mes
# 2015-01-01                  3.595407e+06        4.274443e+06
# 2015-02-01                  3.229374e+06        4.274443e+06
# 2015-03-01                  3.612211e+06        4.274443e+06
# 2015-04-01                  3.515646e+06        5.016966e+06
# 2015-05-01                  3.669902e+06        5.016966e+06
#
#             Juicios Notificados  EMAE Manufactura (y-1)  \
# Año mes
# 2015-01-01                  111                     0.0
# 2015-02-01                 9096                     0.0
# 2015-03-01                10341                     0.0
# 2015-04-01                10074                     0.0
# 2015-05-01                 9827                     0.0
#
#             EMAE Manufactura squared  Produccion Oil m3 Argentina (y-1)  \
# Año mes
# 2015-01-01              13988.440500                                0.0
# 2015-02-01              13651.157891                                0.0
# 2015-03-01              18205.353695                                0.0
# 2015-04-01              18873.647426                                0.0
# 2015-05-01              19421.505492                                0.0
#
#             Produccion Oil m3 Argentina squared  Precio Brent (y-1)  \
# Año mes
# 2015-01-01                         6.373654e+12                 0.0
# 2015-02-01                         5.119065e+12                 0.0
# 2015-03-01                         6.343669e+12                 0.0
# 2015-04-01                         5.978398e+12                 0.0
# 2015-05-01                         6.434196e+12                 0.0
#
#             Precio Brent squared  EMAE Mineria (y-1)  EMAE Mineria squared  \
# Año mes
# 2015-01-01           2280.969840                 0.0           9052.888837
# 2015-02-01           3375.087120                 0.0           7794.853927
# 2015-03-01           3123.184030                 0.0           9481.921310
# 2015-04-01           3543.140590                 0.0           8806.538249
# 2015-05-01           4105.605625                 0.0          10136.164882
#
#             Produccion Gas Mm3 Argentina (y-1)  \
# Año mes
# 2015-01-01                                 0.0
# 2015-02-01                                 0.0
# 2015-03-01                                 0.0
# 2015-04-01                                 0.0
# 2015-05-01                                 0.0
#
#             Produccion Gas Mm3 Argentina squared  PBI Valor Agregado (y-1)  \
# Año mes
# 2015-01-01                          1.292695e+13                       0.0
# 2015-02-01                          1.042885e+13                       0.0
# 2015-03-01                          1.304807e+13                       0.0
# 2015-04-01                          1.235977e+13                       0.0
# 2015-05-01                          1.346818e+13                       0.0
#
#             PBI Valor Agregado squared  Juicios Notificados (y-1)  \
# Año mes
# 2015-01-01                1.827086e+13                        0.0
# 2015-02-01                1.827086e+13                        0.0
# 2015-03-01                1.827086e+13                        0.0
# 2015-04-01                2.516995e+13                        0.0
# 2015-05-01                2.516995e+13                        0.0
#
#             Juicios Notificados squared
# Año mes
# 2015-01-01                        12321
# 2015-02-01                     82737216
# 2015-03-01                    106936281
# 2015-04-01                    101485476
# 2015-05-01                     96569929

# %%
dataset.shape
# Out:
# (60, 23)

# %%
dataset = dataset.loc[dataset.index >= '2018-01-01']

# %%
len(dataset.head(2).columns)
# Out:
# 23

# %%
#Backward Elimination
X = dataset.drop(columns=['Demanda de guantes']).astype(float)
y = dataset['Demanda de guantes']

cols = list(X.columns)
# cols = imp_cols

np.random.shuffle(cols)
pmax = 1
while (len(cols)>0):
    p= []
    
    X_1 = X[cols]
#     X_1 = stm.add_constant(X_1)
    model = stm.OLS(y,X_1).fit()
    
    
    p = pd.Series(model.pvalues.values,index = cols)
    print(p)
    pmax = max(p)
    feature_with_p_max = p.idxmax()

    if(pmax>0.05):
        cols.remove(feature_with_p_max)
    else:
        break

selected_features_BE = cols
# Out:
# Produccion Gas Mm3 Argentina squared    0.030885
# Produccion Gas Mm3 Argentina            0.033832
# Produccion Gas Mm3 Argentina (y-1)      0.069836
# Precio Brent squared                    0.308676
# EMAE Manufactura squared                0.395081
# Precio Brent (y-1)                      0.271129
# EMAE Mineria (y-1)                      0.819814
# Juicios Notificados (y-1)               0.015239
# ITCRM                                   0.302880
# PBI Valor Agregado                      0.838347
# Produccion Oil m3 Argentina             0.516354
# EMAE Mineria                            0.962503
# Produccion Oil m3 Argentina (y-1)       0.784980
# PBI Valor Agregado squared              0.722003
# EMAE Mineria squared                    0.291016
# EMAE Manufactura                        0.922385
# Produccion Oil m3 Argentina squared     0.622973
# PBI Valor Agregado (y-1)                0.548505
# EMAE Manufactura (y-1)                  0.766687
# Precio Brent                            0.941037
# Juicios Notificados squared             0.330422
# Juicios Notificados                     0.089756
# dtype: float64
# Produccion Gas Mm3 Argentina squared    0.030083
# Produccion Gas Mm3 Argentina            0.032914
# Produccion Gas Mm3 Argentina (y-1)      0.069041
# Precio Brent squared                    0.331463
# EMAE Manufactura squared                0.485341
# Precio Brent (y-1)                      0.269379
# EMAE Mineria (y-1)                      0.821107
# Juicios Notificados (y-1)               0.016055
# ITCRM                                   0.299589
# PBI Valor Agregado                      0.850364
# Produccion Oil m3 Argentina             0.494444
# Produccion Oil m3 Argentina (y-1)       0.784712
# PBI Valor Agregado squared              0.732151
# EMAE Mineria squared                    0.247460
# EMAE Manufactura                        0.891781
# Produccion Oil m3 Argentina squared     0.595644
# PBI Valor Agregado (y-1)                0.545969
# EMAE Manufactura (y-1)                  0.775274
# Precio Brent                            0.987020
# Juicios Notificados squared             0.337705
# Juicios Notificados                     0.096768
# dtype: float64
# Produccion Gas Mm3 Argentina squared    0.028439
# Produccion Gas Mm3 Argentina            0.030985
# Produccion Gas Mm3 Argentina (y-1)      0.074049
# Precio Brent squared                    0.015001
# EMAE Manufactura squared                0.668210
# Precio Brent (y-1)                      0.268582
# EMAE Mineria (y-1)                      0.905825
# Juicios Notificados (y-1)               0.015558
# ITCRM                                   0.284881
# PBI Valor Agregado                      0.836929
# Produccion Oil m3 Argentina             0.453290
# Produccion Oil m3 Argentina (y-1)       0.858444
# PBI Valor Agregado squared              0.711016
# EMAE Mineria squared                    0.277533
# EMAE Manufactura                        0.824360
# Produccion Oil m3 Argentina squared     0.544033
# PBI Valor Agregado (y-1)                0.529277
# EMAE Manufactura (y-1)                  0.823336
# Juicios Notificados squared             0.334711
# Juicios Notificados                     0.094787
# dtype: float64
# Produccion Gas Mm3 Argentina squared    0.024266
# Produccion Gas Mm3 Argentina            0.023864
# Produccion Gas Mm3 Argentina (y-1)      0.035225
# Precio Brent squared                    0.007185
# EMAE Manufactura squared                0.677621
# Precio Brent (y-1)                      0.271205
# Juicios Notificados (y-1)               0.009419
# ITCRM                                   0.214108
# PBI Valor Agregado                      0.702664
# Produccion Oil m3 Argentina             0.450035
# Produccion Oil m3 Argentina (y-1)       0.855399
# PBI Valor Agregado squared              0.472512
# EMAE Mineria squared                    0.177137
# EMAE Manufactura                        0.798180
# Produccion Oil m3 Argentina squared     0.550946
# PBI Valor Agregado (y-1)                0.460328
# EMAE Manufactura (y-1)                  0.842888
# Juicios Notificados squared             0.247811
# Juicios Notificados                     0.055802
# dtype: float64
# Produccion Gas Mm3 Argentina squared    0.009481
# Produccion Gas Mm3 Argentina            0.007782
# Produccion Gas Mm3 Argentina (y-1)      0.019288
# Precio Brent squared                    0.002349
# EMAE Manufactura squared                0.608611
# Precio Brent (y-1)                      0.234617
# Juicios Notificados (y-1)               0.004611
# ITCRM                                   0.074974
# PBI Valor Agregado                      0.671508
# Produccion Oil m3 Argentina             0.378270
# PBI Valor Agregado squared              0.281038
# EMAE Mineria squared                    0.133703
# EMAE Manufactura                        0.797536
# Produccion Oil m3 Argentina squared     0.518839
# PBI Valor Agregado (y-1)                0.214339
# EMAE Manufactura (y-1)                  0.873964
# Juicios Notificados squared             0.151114
# Juicios Notificados                     0.028537
# dtype: float64
# Produccion Gas Mm3 Argentina squared    0.004681
# Produccion Gas Mm3 Argentina            0.003762
# Produccion Gas Mm3 Argentina (y-1)      0.003967
# Precio Brent squared                    0.000079
# EMAE Manufactura squared                0.588917
# Precio Brent (y-1)                      0.205242
# Juicios Notificados (y-1)               0.001397
# ITCRM                                   0.003200
# PBI Valor Agregado                      0.664633
# Produccion Oil m3 Argentina             0.331112
# PBI Valor Agregado squared              0.244729
# EMAE Mineria squared                    0.079749
# EMAE Manufactura                        0.727297
# Produccion Oil m3 Argentina squared     0.465717
# PBI Valor Agregado (y-1)                0.086488
# Juicios Notificados squared             0.064708
# Juicios Notificados                     0.018122
# dtype: float64
# Produccion Gas Mm3 Argentina squared    0.001072
# Produccion Gas Mm3 Argentina            0.000711
# Produccion Gas Mm3 Argentina (y-1)      0.004236
# Precio Brent squared                    0.000055
# EMAE Manufactura squared                0.000099
# Precio Brent (y-1)                      0.216929
# Juicios Notificados (y-1)               0.001074
# ITCRM                                   0.003216
# PBI Valor Agregado                      0.563962
# Produccion Oil m3 Argentina             0.142299
# PBI Valor Agregado squared              0.190463
# EMAE Mineria squared                    0.085764
# Produccion Oil m3 Argentina squared     0.324405
# PBI Valor Agregado (y-1)                0.091026
# Juicios Notificados squared             0.046139
# Juicios Notificados                     0.010427
# dtype: float64
# Produccion Gas Mm3 Argentina squared    0.000616
# Produccion Gas Mm3 Argentina            0.000388
# Produccion Gas Mm3 Argentina (y-1)      0.002822
# Precio Brent squared                    0.000018
# EMAE Manufactura squared                0.000041
# Precio Brent (y-1)                      0.242441
# Juicios Notificados (y-1)               0.000217
# ITCRM                                   0.001706
# Produccion Oil m3 Argentina             0.107885
# PBI Valor Agregado squared              0.143452
# EMAE Mineria squared                    0.073110
# Produccion Oil m3 Argentina squared     0.274092
# PBI Valor Agregado (y-1)                0.038259
# Juicios Notificados squared             0.038629
# Juicios Notificados                     0.007719
# dtype: float64
# Produccion Gas Mm3 Argentina squared    0.000021
# Produccion Gas Mm3 Argentina            0.000026
# Produccion Gas Mm3 Argentina (y-1)      0.000834
# Precio Brent squared                    0.000011
# EMAE Manufactura squared                0.000020
# Precio Brent (y-1)                      0.550789
# Juicios Notificados (y-1)               0.000138
# ITCRM                                   0.000512
# Produccion Oil m3 Argentina             0.022258
# PBI Valor Agregado squared              0.018139
# EMAE Mineria squared                    0.101891
# PBI Valor Agregado (y-1)                0.004679
# Juicios Notificados squared             0.024980
# Juicios Notificados                     0.005481
# dtype: float64
# Produccion Gas Mm3 Argentina squared    2.395867e-06
# Produccion Gas Mm3 Argentina            1.922596e-06
# Produccion Gas Mm3 Argentina (y-1)      5.246748e-04
# Precio Brent squared                    7.943719e-07
# EMAE Manufactura squared                7.843482e-06
# Juicios Notificados (y-1)               5.899111e-05
# ITCRM                                   5.309046e-05
# Produccion Oil m3 Argentina             8.189822e-03
# PBI Valor Agregado squared              7.622165e-03
# EMAE Mineria squared                    7.394786e-02
# PBI Valor Agregado (y-1)                1.956014e-03
# Juicios Notificados squared             2.097545e-02
# Juicios Notificados                     3.737681e-03
# dtype: float64
# Produccion Gas Mm3 Argentina squared    4.015968e-06
# Produccion Gas Mm3 Argentina            3.283865e-06
# Produccion Gas Mm3 Argentina (y-1)      1.429023e-03
# Precio Brent squared                    1.158258e-06
# EMAE Manufactura squared                7.666241e-07
# Juicios Notificados (y-1)               9.493327e-05
# ITCRM                                   1.195932e-04
# Produccion Oil m3 Argentina             2.963621e-02
# PBI Valor Agregado squared              8.311291e-03
# PBI Valor Agregado (y-1)                1.607566e-03
# Juicios Notificados squared             2.407558e-02
# Juicios Notificados                     5.293404e-03
# dtype: float64

# %%
len(selected_features_BE)
# Out:
# 12

# %%
selected_features_BE
# Out:
# ['PBI Valor Agregado (y-1)',
#  'PBI Valor Agregado squared',
#  'Produccion Gas Mm3 Argentina',
#  'Juicios Notificados',
#  'Juicios Notificados squared',
#  'ITCRM',
#  'Juicios Notificados (y-1)',
#  'Produccion Gas Mm3 Argentina squared',
#  'Produccion Gas Mm3 Argentina (y-1)',
#  'EMAE Manufactura squared',
#  'Precio Brent squared',
#  'Produccion Oil m3 Argentina']

# %%
X_sf = dataset[selected_features_BE]

X_sf = stm.add_constant(X_sf)
Y = dataset['Demanda de guantes']

model = stm.OLS(Y,X_sf, hasconst=True)

results = model.fit()
results.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                              Results: Ordinary least squares
# ==========================================================================================
# Model:                     OLS                       Adj. R-squared:            0.867
# Dependent Variable:        Demanda de guantes        AIC:                       546.5903
# Date:                      2020-04-25 23:52          BIC:                       560.7270
# No. Observations:          24                        Log-Likelihood:            -261.30
# Df Model:                  11                        F-statistic:               14.62
# Df Residuals:              12                        Prob (F-statistic):        2.69e-05
# R-squared:                 0.931                     Scale:                     3.3508e+08
# ------------------------------------------------------------------------------------------
#                                        Coef.   Std.Err.    t    P>|t|    [0.025    0.975]
# ------------------------------------------------------------------------------------------
# const                                  -0.0903   0.0162 -5.5697 0.0001   -0.1256   -0.0550
# Produccion Gas Mm3 Argentina squared   -0.0000   0.0000 -7.9486 0.0000   -0.0000   -0.0000
# Produccion Gas Mm3 Argentina            0.6160   0.0760  8.1063 0.0000    0.4505    0.7816
# Produccion Gas Mm3 Argentina (y-1)     -0.1735   0.0422 -4.1167 0.0014   -0.2654   -0.0817
# Precio Brent squared                  -68.6164   7.6587 -8.9593 0.0000  -85.3033  -51.9295
# EMAE Manufactura squared               42.0422   4.5134  9.3150 0.0000   32.2084   51.8760
# Juicios Notificados (y-1)             -33.4282   5.8365 -5.7275 0.0001  -46.1447  -20.7116
# ITCRM                                2789.0988 499.6965  5.5816 0.0001 1700.3538 3877.8439
# Produccion Oil m3 Argentina            -0.2023   0.0820 -2.4674 0.0296   -0.3809   -0.0237
# PBI Valor Agregado squared              0.0000   0.0000  3.1541 0.0083    0.0000    0.0000
# PBI Valor Agregado (y-1)               -0.1075   0.0265 -4.0510 0.0016   -0.1654   -0.0497
# Juicios Notificados squared            -0.0030   0.0011 -2.5805 0.0241   -0.0055   -0.0005
# Juicios Notificados                    57.5706  16.9446  3.3976 0.0053   20.6514   94.4897
# ------------------------------------------------------------------------------------------
# Omnibus:                  3.788             Durbin-Watson:               3.061
# Prob(Omnibus):            0.150             Jarque-Bera (JB):            2.221
# Skew:                     -0.516            Prob(JB):                    0.329
# Kurtosis:                 1.926             Condition No.:               18351235280272804
# ==========================================================================================
# * The condition number is large (2e+16). This might indicate             strong
# multicollinearity or other numerical problems.
# """

# %%
np.sort(selected_features_BE).tolist()
# Out:
# ['EMAE Manufactura squared',
#  'ITCRM',
#  'Juicios Notificados',
#  'Juicios Notificados (y-1)',
#  'Juicios Notificados squared',
#  'PBI Valor Agregado (y-1)',
#  'PBI Valor Agregado squared',
#  'Precio Brent squared',
#  'Produccion Gas Mm3 Argentina',
#  'Produccion Gas Mm3 Argentina (y-1)',
#  'Produccion Gas Mm3 Argentina squared',
#  'Produccion Oil m3 Argentina']

# %%
X_sf = dataset[['EMAE Manufactura squared',
 'ITCRM',
 'Juicios Notificados',
 'Juicios Notificados (y-1)',
 'Juicios Notificados squared',
 'PBI Valor Agregado (y-1)',
 'PBI Valor Agregado squared',
 'Precio Brent squared',
 'Produccion Gas Mm3 Argentina',
 'Produccion Gas Mm3 Argentina (y-1)',
 'Produccion Gas Mm3 Argentina squared',
 'Produccion Oil m3 Argentina'
               ]]

X_sf = stm.add_constant(X_sf)
Y = dataset['Demanda de guantes']

model = stm.OLS(Y,X_sf, hasconst=True)

results = model.fit()
results.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                              Results: Ordinary least squares
# ==========================================================================================
# Model:                     OLS                       Adj. R-squared:            0.867
# Dependent Variable:        Demanda de guantes        AIC:                       546.5903
# Date:                      2020-04-25 23:50          BIC:                       560.7270
# No. Observations:          24                        Log-Likelihood:            -261.30
# Df Model:                  11                        F-statistic:               14.62
# Df Residuals:              12                        Prob (F-statistic):        2.69e-05
# R-squared:                 0.931                     Scale:                     3.3508e+08
# ------------------------------------------------------------------------------------------
#                                        Coef.   Std.Err.    t    P>|t|    [0.025    0.975]
# ------------------------------------------------------------------------------------------
# const                                  -0.0902   0.0162 -5.5696 0.0001   -0.1256   -0.0549
# EMAE Manufactura squared               42.0422   4.5134  9.3150 0.0000   32.2084   51.8760
# ITCRM                                2789.0611 499.6963  5.5815 0.0001 1700.3164 3877.8058
# Juicios Notificados                    57.5693  16.9446  3.3975 0.0053   20.6502   94.4883
# Juicios Notificados (y-1)             -33.4279   5.8364 -5.7274 0.0001  -46.1444  -20.7114
# Juicios Notificados squared            -0.0030   0.0011 -2.5804 0.0241   -0.0055   -0.0005
# PBI Valor Agregado (y-1)               -0.1075   0.0265 -4.0509 0.0016   -0.1654   -0.0497
# PBI Valor Agregado squared              0.0000   0.0000  3.1542 0.0083    0.0000    0.0000
# Precio Brent squared                  -68.6164   7.6587 -8.9592 0.0000  -85.3033  -51.9294
# Produccion Gas Mm3 Argentina            0.6160   0.0760  8.1063 0.0000    0.4505    0.7816
# Produccion Gas Mm3 Argentina (y-1)     -0.1735   0.0422 -4.1167 0.0014   -0.2654   -0.0817
# Produccion Gas Mm3 Argentina squared   -0.0000   0.0000 -7.9486 0.0000   -0.0000   -0.0000
# Produccion Oil m3 Argentina            -0.2023   0.0820 -2.4674 0.0296   -0.3809   -0.0237
# ------------------------------------------------------------------------------------------
# Omnibus:                  3.789             Durbin-Watson:               3.061
# Prob(Omnibus):            0.150             Jarque-Bera (JB):            2.221
# Skew:                     -0.516            Prob(JB):                    0.329
# Kurtosis:                 1.926             Condition No.:               18351232556093848
# ==========================================================================================
# * The condition number is large (2e+16). This might indicate             strong
# multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## Combino ambos resultados

# %%
X_sf = dataset[[
    'ITCRM (y-1)',
    'EMAE Manufactura (y-1)',
    'Juicios sin Sentencia (y-1)',
    'EMAE Construccion',
#     'Produccion Oil m3 Patagonia',
#     'PBI Valor Agregado',
#     'Produccion Oil m3 Argentina',
    'Precio Brent'
               ]]
# X_sf = dataset[['Juicios Notificados', 'Juicios con Sentencia', 'Juicios sin Sentencia']]
y = dataset['Demanda de guantes']

X_sf = stm.add_constant(X_sf)
Y = dataset['Demanda de guantes']

model = stm.OLS(Y,X_sf, hasconst=True)

results = model.fit()
results.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                               Results: Ordinary least squares
# ============================================================================================
# Model:                       OLS                       Adj. R-squared:            0.437
# Dependent Variable:          Demanda de guantes        AIC:                       578.9450
# Date:                        2020-04-25 19:51          BIC:                       586.0133
# No. Observations:            24                        Log-Likelihood:            -283.47
# Df Model:                    5                         F-statistic:               4.567
# Df Residuals:                18                        Prob (F-statistic):        0.00727
# R-squared:                   0.559                     Scale:                     1.4180e+09
# --------------------------------------------------------------------------------------------
#                                Coef.       Std.Err.     t    P>|t|     [0.025       0.975]
# --------------------------------------------------------------------------------------------
# const                       -244469.3445 201419.1130 -1.2137 0.2405 -667635.1982 178696.5093
# ITCRM (y-1)                    1344.7960    582.7629  2.3076 0.0331     120.4565   2569.1355
# EMAE Manufactura (y-1)         2945.6651    962.7843  3.0595 0.0068     922.9304   4968.3998
# Juicios sin Sentencia (y-1)     -11.6216      5.1590 -2.2527 0.0370     -22.4602     -0.7830
# EMAE Construccion              1375.3863    845.1326  1.6274 0.1210    -400.1715   3150.9441
# Precio Brent                  -2976.6330   1489.3084 -1.9987 0.0610   -6105.5539    152.2879
# --------------------------------------------------------------------------------------------
# Omnibus:                       1.321                 Durbin-Watson:                   2.130
# Prob(Omnibus):                 0.516                 Jarque-Bera (JB):                0.569
# Skew:                          -0.369                Prob(JB):                        0.753
# Kurtosis:                      3.152                 Condition No.:                   133216
# ============================================================================================
# * The condition number is large (1e+05). This might indicate             strong
# multicollinearity or other numerical problems.
# """

# %% [markdown]
# # MVP

# %%
dataset = pd.read_excel('./Data para Proyecciones/Dataset_Proyecciones.xlsx')
dataset.head()
# Out:
#    Demanda de guantes      ITCRM  EMAE Manufactura (t -1)  EMAE Manufactura  \
# 0       275118.860759  79.543955               133.862326        118.272738
# 1       257997.421384  78.841323               118.272738        116.838170
# 2       255388.500000  78.487223               116.838170        134.927216
# 3       204928.248447  77.783166               134.927216        137.381394
# 4       236073.407407  77.087749               137.381394        139.361062
#
#    EMAE Construccion (t-1)  EMAE Construccion  Produccion Oil m3 Argentina  \
# 0               139.964452         146.689712                 2.524610e+06
# 1               146.689712         147.782989                 2.262535e+06
# 2               147.782989         151.920156                 2.518664e+06
# 3               151.920156         151.984589                 2.445076e+06
# 4               151.984589         153.409565                 2.536572e+06
#
#    Produccion Oil m3 Patagonia  Precio Brent (t-1)  Precio Brent (y - 1)  ...  \
# 0                 2.387218e+06           62.335000            108.117727  ...
# 1                 2.142219e+06           47.759500            108.900526  ...
# 2                 2.384975e+06           58.095500            107.480952  ...
# 3                 2.315147e+06           55.885455            107.755238  ...
# 4                 2.406750e+06           59.524286            109.539091  ...
#
#    EMAE Mineria (t-1)  EMAE Mineria  Produccion Gas Mm3 Argentina  \
# 0           94.773137     95.146670                  3.595407e+06
# 1           95.146670     88.288470                  3.229374e+06
# 2           88.288470     97.375158                  3.612211e+06
# 3           97.375158     93.843158                  3.515646e+06
# 4           93.843158    100.678522                  3.669902e+06
#
#    Produccion Gas Mm3 Patagonia  PBI Valor Agregado  Juicios Notificados  \
# 0                  2.908825e+06        4.274443e+06                  111
# 1                  2.628789e+06        4.274443e+06                 9096
# 2                  2.936375e+06        4.274443e+06                10341
# 3                  2.818163e+06        5.016966e+06                10074
# 4                  2.945839e+06        5.016966e+06                 9827
#
#    Juicios Sin Resolver  Juicios con Sentencia  Juicios sin Sentencia  \
# 0                 66075                     69                     42
# 1                 68487                   6642                   2452
# 2                 71465                   7335                   3008
# 3                 74450                   7043                   3030
# 4                 77244                   6985                   2843
#
#      Año mes
# 0 2015-01-01
# 1 2015-02-01
# 2 2015-03-01
# 3 2015-04-01
# 4 2015-05-01
#
# [5 rows x 21 columns]

# %%
dataset = dataset.loc[dataset['Año mes'] > '2018-01-01']

# %%
dataset.drop(columns=['Año mes'], inplace=True)

# %%
X = dataset[[
    'EMAE Construccion',
    'Produccion Oil m3 Patagonia',
    'Produccion Oil m3 Argentina',
    'PBI Valor Agregado',
    'Precio Brent',
]].astype(float)

X = sm.add_constant(X)
y = dataset['Demanda de guantes']


results = sm.OLS(y, X, ).fit()
results.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                               Results: Ordinary least squares
# ============================================================================================
# Model:                       OLS                       Adj. R-squared:            0.416
# Dependent Variable:          Demanda de guantes        AIC:                       556.7560
# Date:                        2020-04-26 13:34          BIC:                       563.5690
# No. Observations:            23                        Log-Likelihood:            -272.38
# Df Model:                    5                         F-statistic:               4.133
# Df Residuals:                17                        Prob (F-statistic):        0.0122
# R-squared:                   0.549                     Scale:                     1.5314e+09
# --------------------------------------------------------------------------------------------
#                                Coef.       Std.Err.     t    P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       -665430.3268 352704.6587 -1.8867 0.0764 -1409572.1102 78711.4566
# EMAE Construccion              4068.7692   1270.9796  3.2013 0.0052     1387.2367  6750.3017
# Produccion Oil m3 Patagonia      -8.1214      3.2439 -2.5036 0.0228      -14.9655    -1.2774
# Produccion Oil m3 Argentina       7.8847      3.2062  2.4592 0.0249        1.1202    14.6492
# PBI Valor Agregado                0.0269      0.0085  3.1807 0.0055        0.0091     0.0447
# Precio Brent                  -4689.9300   1611.2361 -2.9108 0.0097    -8089.3410 -1290.5189
# --------------------------------------------------------------------------------------------
# Omnibus:                      0.521                Durbin-Watson:                  2.434
# Prob(Omnibus):                0.771                Jarque-Bera (JB):               0.226
# Skew:                         -0.238               Prob(JB):                       0.893
# Kurtosis:                     2.909                Condition No.:                  701662637
# ============================================================================================
# * The condition number is large (7e+08). This might indicate             strong
# multicollinearity or other numerical problems.
# """

# %%
mvp = results

# %% [markdown]
# # Proyeccion de Variables hasta 2023

# %% [markdown]
# ## EMAE Construccion

# %%
emae_construccion = pd.read_excel('./Data para Proyecciones/EMAE_mensual_v1.xlsx', sheet_name='Construccion')
emae_construccion.head()
# Out:
#   EMAE Construccion  Unnamed: 1
# 0        2004-01-01   95.938047
# 1        2004-02-01   98.853388
# 2        2004-03-01  103.124529
# 3        2004-04-01   95.815492
# 4        2004-05-01   97.994567

# %%
emae_construccion.columns = ['fecha', 'EMAE']

# %%
emae_construccion.fecha = pd.to_datetime(emae_construccion.fecha, format='%Y-%m-%d')
emae_construccion.set_index('fecha', inplace=True)
emae_construccion.head()
# Out:
#                   EMAE
# fecha
# 2004-01-01   95.938047
# 2004-02-01   98.853388
# 2004-03-01  103.124529
# 2004-04-01   95.815492
# 2004-05-01   97.994567

# %%
emae_construccion.plot()

# %%
emae_construccion = emae_construccion.loc[emae_construccion.index >= '2011-01-01']

# %%
emae_construccion.plot()

# %% [markdown]
# ### Estandarizo armado de analisis ARIMA

# %%
import itertools

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %%
import statsmodels.api as sm

# %%
data = {}

results_df = pd.DataFrame()

y = emae_construccion
i = 0
for param in pdq:
    for param_seasonal in seasonal_pdq:
        mod = sm.tsa.statespace.SARIMAX(y,
                                        order=param,
                                        freq='MS',
                                        seasonal_order=param_seasonal,
                                        enforce_stationarity=False,
                                        enforce_invertibility=False)

        results = mod.fit()
        print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        data['iter'] = i
        data['p'] = param[0]
        data['d'] = param[1]
        data['q'] = param[2]

        data['s_p'] = param_seasonal[0]
        data['s_d'] = param_seasonal[1]
        data['s_q'] = param_seasonal[2]
        
        data['AIC'] = results.aic
        
        aux_df = pd.DataFrame(data=data, index=[0])
        
        results_df = pd.concat([results_df, aux_df], axis=0, ignore_index=True)
        
        i += 1
# Out:
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:1374.5692269235708
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:1126.975599812121
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:725.0690354170864
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:603.143263094832
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:730.82997162639
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:674.0507839392133
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:622.1405179256205
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:601.5733280603841
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:1232.8754227929337
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:1001.1527153820049
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:639.9456673022075
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:544.532279588192
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:651.8715158615979
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:644.5752998795036
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:564.1695721345808
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:547.3536966996497
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:704.9245028110151
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:596.8262355058158
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:567.9505500541487
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:495.7150538417085
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:568.7436602797625
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:563.0914070270788
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:503.23908445698135
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:499.7074649927151
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:682.114665577242
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:587.041362896273
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:562.8903735575617
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:485.935017496592
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:567.7050801961711
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:553.5180411406931
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:499.1180905204739
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:490.18360892254873
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:712.2891708704148
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:603.9302313505266
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:570.7265322344533
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:498.37569861483075
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:569.4793356372612
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:564.9737316221538
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:501.17107381716505
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:502.4604396258791
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:689.2188716994283
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:594.2584162765214
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:566.5469158430952
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:490.9782988036319
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:568.762679833674
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:557.7268622408164
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:499.33159561858514
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:495.31464800181345
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:686.2537535546787
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:591.0632860597482
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:567.7024593853265
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:489.919124705218
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:562.2739849240158
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:557.54752622745
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:493.3207291296617
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:494.2832734725681
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:682.3578794568454
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:587.6829897570932
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:564.6835126318703
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:486.74550470127605
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:564.2532490982292
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:554.1490916884115
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:495.1074730450312
# C:\Users\jhevia\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   % freq, ValueWarning)
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:491.0466852505155

# %%
def ARIMA_summary(y,results_df):
    
    best_pdq = tuple(results_df.loc[results_df.AIC == results_df.AIC.min(), ['p', 'd', 'q']].values[0])    
    best_s_pdq = tuple(results_df.loc[results_df.AIC == results_df.AIC.min(), ['s_p', 's_d', 's_q', 's_M']].values[0])
    
    print(f'BEST ARIMA : {best_pdq} x {best_s_pdq}')
    
    mod = sm.tsa.statespace.SARIMAX(y,
                                    order=best_pdq,
                                    seasonal_order=best_s_pdq,
                                    enforce_stationarity=False,
                                    enforce_invertibility=False)
    results = mod.fit()
    print(results.summary().tables[1])

    results.plot_diagnostics(figsize=(16, 8))
    plt.show()
    
    return results
    
# plot_ARIMA_summary(emae_construccion, results_df)

# %%
def plot_proyecciones(time_series, results_ARIMA, init_year='2014', starting_year='2018'):
    plt.clf()
    
    pred = results_ARIMA.get_prediction(start=pd.to_datetime(f'{starting_year}-01-01'), end=pd.to_datetime('2026-01-01'),
                                  dynamic=False)
    pred_ci = pred.conf_int()
    ax = time_series[init_year:].plot(label='observed')
    pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))
    ax.fill_between(pred_ci.index,
                    pred_ci.iloc[:, 0],
                    pred_ci.iloc[:, 1], color='k', alpha=.2)
    ax.set_xlabel('Date')
    ax.set_ylabel('Furniture Sales')
    plt.legend()

    plt.tight_layout()
    
    return pred.predicted_mean
    
# plot_proyecciones(results)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
def get_proyeccion_SARIMA(ts_a_proyectar, plot_init_year='2014', pred_starting_year='2018'):
    
    p = d = q = range(0, 2)
    pdq = list(itertools.product(p, d, q))
    seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
    
    i=0
    results_df = pd.DataFrame()
    for param in pdq:
        for param_seasonal in seasonal_pdq:
            
            mod = sm.tsa.statespace.SARIMAX(ts_a_proyectar,
                                            order=param,
                                            freq='MS',
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit(freq='MS')
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
            data['iter'] = i
            data['p'] = param[0]
            data['d'] = param[1]
            data['q'] = param[2]

            data['s_p'] = param_seasonal[0]
            data['s_d'] = param_seasonal[1]
            data['s_q'] = param_seasonal[2]
            data['s_M'] = 12

            data['AIC'] = results.aic

            aux_df = pd.DataFrame(data=data, index=[0])

            results_df = pd.concat([results_df, aux_df], axis=0, ignore_index=True)

            i += 1
    
    results = ARIMA_summary(ts_a_proyectar, results_df)
    
    prediccion = plot_proyecciones(ts_a_proyectar, results, init_year=plot_init_year, starting_year=pred_starting_year)
    
    return prediccion


# prediccion_EMAE_CONSTRUCCION = get_proyeccion_SARIMA(emae_construccion)

# %% [markdown]
# ## Produccion Oil m3 Argentina

# %%
idx = pd.date_range(start='2015-01-01', end='2019-12-01', freq='MS')
idx
# Out:
# DatetimeIndex(['2015-01-01', '2015-02-01', '2015-03-01', '2015-04-01',
#                '2015-05-01', '2015-06-01', '2015-07-01', '2015-08-01',
#                '2015-09-01', '2015-10-01', '2015-11-01', '2015-12-01',
#                '2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01',
#                '2016-05-01', '2016-06-01', '2016-07-01', '2016-08-01',
#                '2016-09-01', '2016-10-01', '2016-11-01', '2016-12-01',
#                '2017-01-01', '2017-02-01', '2017-03-01', '2017-04-01',
#                '2017-05-01', '2017-06-01', '2017-07-01', '2017-08-01',
#                '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01',
#                '2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01',
#                '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01',
#                '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01',
#                '2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
produccion_oil_argentina = pd.read_excel('./Data para Proyecciones/TD_S_SescoWebUP_02_2020.xlsx', sheet_name='Oil Production Argentina').astype(int)
produccion_oil_argentina.set_index(idx, inplace=True)

# %%
produccion_oil_argentina.plot()

# %%
prediccion_OIL_ARGENTINA = get_proyeccion_SARIMA(produccion_oil_argentina.loc[produccion_oil_argentina.index >= '2016-01-01'],
                                                pred_starting_year='2019')
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:1689.580054394801
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:66870450.46469085
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:98883475.44344053
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:667.4085744430533
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:1016.0203168605624
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:61348406.987823136
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:690.3943026474813
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:665.3956906668938
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:1454.5813635105599
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:61596157.87877097
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:949.3260168307179
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:618.171971905622
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:1131.2590622872995
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:56092292.12466239
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:673.7926005315094
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:620.1525215238902
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:1233.9305580560297
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:86981.41703224415
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:888.3655431857828
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:554.774709746784
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:907.8369911468392
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:86795.80990912937
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:599.9893069825865
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:556.7096596236343
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:1183.3868716071875
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:48156.54220267217
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:856.5117025076108
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:530.9410722298628
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:912.8612533585871
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:56083.14604734068
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:602.2673094121731
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:532.5806734684378
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:1252.1531412154316
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:121173.60786945798
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:907.8244394848194
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:585.2129444507055
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:917.2932165264971
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:120260.0373753723
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:601.7996011665658
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:587.0806689292353
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:1209.1236869399663
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:86990.22444502579
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:883.0781114934996
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:557.6515892942956
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:913.4791498803831
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:86607.3725554497
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:603.7686968727373
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:559.2190288989311
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:1202.3360272919617
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:45108.472688920156
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:880.9675177089897
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:557.3640057171613
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:883.5345118507473
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:43870.540597327985
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:577.2772588215115
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:558.9176436939744
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:1178.8546521938745
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:39380.81180439286
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:858.1490917608828
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:532.8067155519556
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:885.9447425790671
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:38541.51469922655
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:579.3653842999802
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:534.7601019384211
# BEST ARIMA : (0, 1, 1) x (0, 1, 1, 12)
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.4212      0.721     -0.584      0.559      -1.834       0.992
# ma.S.L12      -0.5108      0.128     -3.975      0.000      -0.763      -0.259
# sigma2      8.988e+09   3.22e-11   2.79e+20      0.000    8.99e+09    8.99e+09
# ==============================================================================

# %% [markdown]
# ## Produccion Oil Patagonia

# %%
idx = pd.date_range(start='2015-01-01', end='2019-12-01', freq='MS')
idx
# Out:
# DatetimeIndex(['2015-01-01', '2015-02-01', '2015-03-01', '2015-04-01',
#                '2015-05-01', '2015-06-01', '2015-07-01', '2015-08-01',
#                '2015-09-01', '2015-10-01', '2015-11-01', '2015-12-01',
#                '2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01',
#                '2016-05-01', '2016-06-01', '2016-07-01', '2016-08-01',
#                '2016-09-01', '2016-10-01', '2016-11-01', '2016-12-01',
#                '2017-01-01', '2017-02-01', '2017-03-01', '2017-04-01',
#                '2017-05-01', '2017-06-01', '2017-07-01', '2017-08-01',
#                '2017-09-01', '2017-10-01', '2017-11-01', '2017-12-01',
#                '2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01',
#                '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01',
#                '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01',
#                '2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
produccion_oil_patagonia = pd.read_excel('./Data para Proyecciones/TD_S_SescoWebUP_02_2020.xlsx', sheet_name='Oil Production Patagonia').astype(int)
produccion_oil_patagonia.set_index(idx, inplace=True)

# %%
produccion_oil_patagonia.plot()

# %%
prediccion_OIL_PATAGONIA = get_proyeccion_SARIMA(produccion_oil_patagonia.loc[produccion_oil_patagonia.index >= '2016-01-01'],
                                                pred_starting_year='2019')
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:1670.127261143568
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:60634893.15687496
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:98163590.40614438
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:667.8670427629963
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:1014.9836741484734
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:55628320.4855224
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:690.081462969837
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:665.8974657753831
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:1450.703589049467
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:55885433.778262176
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:949.112605855139
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:618.1422689830115
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:1128.2496052355648
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:50891983.44307412
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:673.7460593596978
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:620.1279354450942
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:20723870.87816753
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:79224.95205762393
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:nan
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:554.8566938777685
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:908.0337221215487
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:79007.21941569992
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:599.9589590327988
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:556.7592471737718
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:1181.757211459091
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:43227.97958213407
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:856.6616097687095
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:530.9843619795539
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:912.5459899973337
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:50133.78808221202
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:602.1873184402773
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:532.6930804091264
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:1250.0199881678745
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:112919.246414595
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:908.045109868141
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:585.3453127060448
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:916.3995305968745
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:112227.55263083417
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:601.7535515129731
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:587.2842658549041
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:1207.2399035771728
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:79024.14324118709
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:883.2467791733441
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:557.6157284737674
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:913.2111317225877
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:78775.69725838314
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:603.6769973748377
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:559.2609544010772
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:1200.8722730901195
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:40915.2539776429
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:881.0598024068966
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:557.3240050809313
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:883.2981712511498
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:39779.62806266239
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:577.2178927319404
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:558.8258470542128
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:1177.4632180116762
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:35681.27744285316
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:858.2586353421782
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:532.7794405820995
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:885.6795623106532
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:34917.26881119029
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:579.2712851523488
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:534.7111677456526
# BEST ARIMA : (0, 1, 1) x (0, 1, 1, 12)
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.4067      0.798     -0.510      0.610      -1.971       1.157
# ma.S.L12      -0.5213      0.129     -4.056      0.000      -0.773      -0.269
# sigma2      9.032e+09   4.13e-11   2.19e+20      0.000    9.03e+09    9.03e+09
# ==============================================================================

# %% [markdown]
# ## PBI Valor Agregado

# %%
serie_PBI_VA = pd.read_excel('./Data para Proyecciones/Dataset_Proyecciones.xlsx')
serie_PBI_VA = serie_PBI_VA[['Año mes', 'PBI Valor Agregado']]
serie_PBI_VA['Año mes'] = pd.to_datetime(serie_PBI_VA['Año mes'], format='%Y-%m-%d')
serie_PBI_VA.set_index('Año mes', inplace=True)
serie_PBI_VA = serie_PBI_VA.astype(int)
serie_PBI_VA
# Out:
#             PBI Valor Agregado
# Año mes
# 2015-01-01             4274443
# 2015-02-01             4274443
# 2015-03-01             4274443
# 2015-04-01             5016966
# 2015-05-01             5016966
# 2015-06-01             5016966
# 2015-07-01             5226640
# 2015-08-01             5226640
# 2015-09-01             5226640
# 2015-10-01             5518793
# 2015-11-01             5518793
# 2015-12-01             5518793
# 2016-01-01             5886895
# 2016-02-01             5886895
# 2016-03-01             5886895
# 2016-04-01             7143104
# 2016-05-01             7143104
# 2016-06-01             7143104
# 2016-07-01             7191207
# 2016-08-01             7191207
# 2016-09-01             7191207
# 2016-10-01             7570524
# 2016-11-01             7570524
# 2016-12-01             7570524
# 2017-01-01             7765458
# 2017-02-01             7765458
# 2017-03-01             7765458
# 2017-04-01             8978147
# 2017-05-01             8978147
# 2017-06-01             8978147
# 2017-07-01             9301026
# 2017-08-01             9301026
# 2017-09-01             9301026
# 2017-10-01             9856050
# 2017-11-01             9856050
# 2017-12-01             9856050
# 2018-01-01            10334184
# 2018-02-01            10334184
# 2018-03-01            10334184
# 2018-04-01            12044586
# 2018-05-01            12044586
# 2018-06-01            12044586
# 2018-07-01            12717964
# 2018-08-01            12717964
# 2018-09-01            12717964
# 2018-10-01            14299332
# 2018-11-01            14299332
# 2018-12-01            14299332
# 2019-01-01            14799379
# 2019-02-01            14799379
# 2019-03-01            14799379
# 2019-04-01            18238505
# 2019-05-01            18238505
# 2019-06-01            18238505
# 2019-07-01            18560856
# 2019-08-01            18560856
# 2019-09-01            18560856
# 2019-10-01            21110893
# 2019-11-01            21110893
# 2019-12-01            21110893

# %%
serie_PBI_VA.plot()

# %%
prediccion_PBI_VA = get_proyeccion_SARIMA(serie_PBI_VA)
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:3041.6273298419287
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:336255789.85675335
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:1879.6499160490357
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:3316.903414502136
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:1426.4503451538753
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:1400.9906797810238
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:1085.2697307235187
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:3217.0207624539603
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:2014.6851465275242
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:241520855.89905643
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:1497.2958144776724
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:3329.2441198633455
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:1656.414128691662
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:1589.61881620878
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:1163.9827041000615
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:3267.381109009446
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:1804.3020746320744
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:1374.9816040000242
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:nan
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:3277.0427551793427
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:1300.949817847978
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:1274.6534878365771
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:992.8572640332546
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:969.7558449779419
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:1702.7137342091253
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:1325.436040107703
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:1284.3584080380194
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:3150.437121938542
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:1365.5566721013686
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:1309.7350938520542
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:995.5113081765065
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:939.482780192805
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:1748.155623661049
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:619674.1685983973
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:1334.3632066443695
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:3257.9086985362783
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:1354.9554763155768
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:1356.6556575293184
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:994.729288789893
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:3194.1673638032366
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:1706.8964309284074
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:612076.0037194942
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:1307.4500565754893
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:3166.7871255371615
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:1352.586198866973
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:1325.7983477391551
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:996.7091412174711
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:3104.9241146536356
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:1731.4989737235114
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:1353.4703580959067
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:1311.7997834536213
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:3244.9617342141605
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:1335.3465949281215
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:1337.1557170562437
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:967.9462029421883
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:966.7526011666737
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:1704.7137342091253
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:1327.4360401090985
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:1286.3584080380194
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:3152.437121938542
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:1338.73812386445
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:1311.7350938520437
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:970.0584851274144
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:941.4827801927506
# BEST ARIMA : (0, 1, 1) x (1, 1, 1, 12)
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1       -5.69e-06   1.42e+04     -4e-10      1.000   -2.79e+04    2.79e+04
# ar.S.L12       0.8471      0.266      3.187      0.001       0.326       1.368
# ma.S.L12       0.2419      0.140      1.726      0.084      -0.033       0.517
# sigma2      1.332e+11      0.002   8.46e+13      0.000    1.33e+11    1.33e+11
# ==============================================================================

# %% [markdown]
# ## Precio Brent

# %%
time_series_brent = pd.read_csv('./Data para Proyecciones/BrentOilPrices.csv')
time_series_brent = time_series_brent[['Date', 'Price']]

time_series_brent.Date = pd.to_datetime(time_series_brent.Date, format='%d-%b-%y')
time_series_brent.set_index('Date', inplace=True)

# %%
time_series_brent = time_series_brent.loc[time_series_brent.index >= '2015-01-01']
time_series_brent = time_series_brent.resample('MS').mean()

# %%
prediccon_BRENT = get_proyeccion_SARIMA(time_series_brent)
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:671.4362009888531
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:504.60357317291124
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:402.8640577993299
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:303.219001535474
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:413.22192530029315
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:388.4908332034367
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:313.7964614909251
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:306.49252210941165
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:585.257151544956
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:437.7291630140851
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:354.029183078748
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:264.0741002877311
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:374.2983305377301
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:361.0111821890291
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:281.92466663478154
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:267.8548094197389
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:356.93519793883956
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:285.6103986576172
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:326.96590319117587
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:228.0444634663768
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:290.71539702173976
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:287.52895886026107
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:238.90669262587548
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:225.80742323191328
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:350.66528134306134
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:279.9163977896568
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:319.4185742854587
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:219.38610511525226
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:291.34756872736176
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:281.7532996339226
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:234.61775127846428
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:219.80373547856394
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:368.6364403671115
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:294.03415582055425
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:332.6175354948104
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:234.47687699360182
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:292.52477035676833
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:294.2397558684173
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:239.44072805169037
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:230.16095148798908
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:357.59860253195177
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:289.90969103445775
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:323.2186333127413
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:226.03551201672138
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:293.27073167582216
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:290.16420158283023
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:234.42813388749775
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:224.49397023501322
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:357.1352595880524
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:286.72047836621385
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:327.4337764038195
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:225.90709786260493
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:286.39438249873183
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:288.3661899864362
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:228.88828355406795
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:225.51340513374834
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:352.565216038694
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:281.79876263719535
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:321.388906407769
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:221.38544424416466
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:288.01813985659976
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:283.605814744029
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:229.56000689239602
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:221.7420678975621
# BEST ARIMA : (0, 1, 1) x (0, 1, 1, 12)
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          0.2734      0.189      1.450      0.147      -0.096       0.643
# ma.S.L12      -1.0000   1.12e+04  -8.91e-05      1.000    -2.2e+04     2.2e+04
# sigma2        19.2273   2.16e+05   8.91e-05      1.000   -4.23e+05    4.23e+05
# ==============================================================================

# %% [markdown]
# # Predigo demanda de antishock

# %%
prediccon_BRENT.head()
# Out:
# 2018-01-01    60.747853
# 2018-02-01    71.897620
# 2018-03-01    63.884743
# 2018-04-01    69.171778
# 2018-05-01    75.483751
# Freq: MS, dtype: float64

# %%
X_predicciones = pd.concat([
    prediccion_EMAE_CONSTRUCCION,
    prediccion_OIL_PATAGONIA,
    prediccion_OIL_ARGENTINA,
    prediccion_PBI_VA,
    prediccon_BRENT,
          ], axis=1)

X_predicciones = X_predicciones.loc[X_predicciones.index >= '2020-01-01']
X_predicciones.head()
# Out:
#                      0             1             2             3          4
# 2020-01-01  133.080417  3.293488e+06  3.394012e+06  2.159155e+07  68.096629
# 2020-02-01  133.074710  3.075666e+06  3.167542e+06  2.159155e+07  63.112743
# 2020-03-01  136.642103  3.296680e+06  3.397515e+06  2.159155e+07  55.077016
# 2020-04-01  127.909303  3.225925e+06  3.322375e+06  2.677435e+07  58.859921
# 2020-05-01  134.871130  3.297982e+06  3.398712e+06  2.677435e+07  61.396319

# %%
mvp.params
# Out:
# const                         -665430.326809
# EMAE Construccion                4068.769186
# Produccion Oil m3 Patagonia        -8.121423
# Produccion Oil m3 Argentina         7.884698
# PBI Valor Agregado                  0.026893
# Precio Brent                    -4689.929959
# dtype: float64

# %%
X_predicciones.values
# Out:
# array([[1.33080417e+02, 3.29348752e+06, 3.39401227e+06, 2.15915537e+07,
#         6.80966288e+01],
#        [1.33074710e+02, 3.07566551e+06, 3.16754238e+06, 2.15915537e+07,
#         6.31127432e+01],
#        [1.36642103e+02, 3.29668040e+06, 3.39751492e+06, 2.15915537e+07,
#         5.50770162e+01],
#        [1.27909303e+02, 3.22592494e+06, 3.32237484e+06, 2.67743480e+07,
#         5.88599207e+01],
#        [1.34871130e+02, 3.29798198e+06, 3.39871190e+06, 2.67743480e+07,
#         6.13963192e+01],
#        [1.26778852e+02, 3.19519178e+06, 3.29063768e+06, 2.67743480e+07,
#         5.84526398e+01],
#        [1.31100941e+02, 3.30049562e+06, 3.40112991e+06, 2.66428334e+07,
#         5.71419570e+01],
#        [1.40291498e+02, 3.37526567e+06, 3.47561907e+06, 2.66428334e+07,
#         5.46354548e+01],
#        [1.29138580e+02, 3.30892761e+06, 3.40792575e+06, 2.66428334e+07,
#         5.79212414e+01],
#        [1.24090109e+02, 3.38777184e+06, 3.48782213e+06, 2.99883477e+07,
#         5.87500183e+01],
#        [1.22391531e+02, 3.30718540e+06, 3.40621063e+06, 2.99883477e+07,
#         5.54441370e+01],
#        [1.11739068e+02, 3.40527745e+06, 3.50681571e+06, 2.99883477e+07,
#         5.55809797e+01],
#        [1.25597648e+02, 3.81512487e+06, 3.91812874e+06, 3.04525853e+07,
#         5.50266279e+01],
#        [1.25591942e+02, 3.59730286e+06, 3.69165885e+06, 3.04525853e+07,
#         5.38849108e+01],
#        [1.29159334e+02, 3.81831775e+06, 3.92163139e+06, 3.04525853e+07,
#         5.42652712e+01],
#        [1.20426534e+02, 3.74756229e+06, 3.84649131e+06, 3.71125273e+07,
#         5.80481758e+01],
#        [1.27388361e+02, 3.81961933e+06, 3.92282837e+06, 3.71125273e+07,
#         6.05845743e+01],
#        [1.19296083e+02, 3.71682913e+06, 3.81475415e+06, 3.71125273e+07,
#         5.76408949e+01],
#        [1.23618172e+02, 3.82213297e+06, 3.92524638e+06, 3.65965207e+07,
#         5.63302121e+01],
#        [1.32808730e+02, 3.89690302e+06, 3.99973554e+06, 3.65965207e+07,
#         5.38237099e+01],
#        [1.21655811e+02, 3.83056496e+06, 3.93204222e+06, 3.65965207e+07,
#         5.71094965e+01],
#        [1.16607341e+02, 3.90940920e+06, 4.01193859e+06, 4.06159233e+07,
#         5.79382733e+01],
#        [1.14908762e+02, 3.82882275e+06, 3.93032710e+06, 4.06159233e+07,
#         5.46323920e+01],
#        [1.04256299e+02, 3.92691480e+06, 4.03093218e+06, 4.06159233e+07,
#         5.47692348e+01],
#        [1.18114879e+02, 4.33676222e+06, 4.44224521e+06, 4.10662480e+07,
#         5.42148829e+01],
#        [1.18109173e+02, 4.11894021e+06, 4.21577532e+06, 4.10662480e+07,
#         5.30731658e+01],
#        [1.21676565e+02, 4.33995511e+06, 4.44574785e+06, 4.10662480e+07,
#         5.34535263e+01],
#        [1.12943765e+02, 4.26919964e+06, 4.37060778e+06, 4.89775552e+07,
#         5.72364309e+01],
#        [1.19905592e+02, 4.34125669e+06, 4.44694484e+06, 4.89775552e+07,
#         5.97728294e+01],
#        [1.11813314e+02, 4.23846648e+06, 4.33887062e+06, 4.89775552e+07,
#         5.68291499e+01],
#        [1.16135403e+02, 4.34377032e+06, 4.44936284e+06, 4.81358263e+07,
#         5.55184671e+01],
#        [1.25325961e+02, 4.41854037e+06, 4.52385201e+06, 4.81358263e+07,
#         5.30119650e+01],
#        [1.14173042e+02, 4.35220231e+06, 4.45615869e+06, 4.81358263e+07,
#         5.62977516e+01],
#        [1.09124572e+02, 4.43104655e+06, 4.53605506e+06, 5.27261130e+07,
#         5.71265284e+01],
#        [1.07425993e+02, 4.35046010e+06, 4.45444357e+06, 5.27261130e+07,
#         5.38206471e+01],
#        [9.67735308e+01, 4.44855215e+06, 4.55504865e+06, 5.27261130e+07,
#         5.39574898e+01],
#        [1.10632111e+02, 4.85839957e+06, 4.96636168e+06, 5.31646515e+07,
#         5.34031380e+01],
#        [1.10626404e+02, 4.64057756e+06, 4.73989178e+06, 5.31646515e+07,
#         5.22614209e+01],
#        [1.14193797e+02, 4.86159246e+06, 4.96986432e+06, 5.31646515e+07,
#         5.26417814e+01],
#        [1.05460997e+02, 4.79083699e+06, 4.89472424e+06, 6.21360520e+07,
#         5.64246859e+01],
#        [1.12422824e+02, 4.86289404e+06, 4.97106131e+06, 6.21360520e+07,
#         5.89610844e+01],
#        [1.04330546e+02, 4.76010383e+06, 4.86298708e+06, 6.21360520e+07,
#         5.60174050e+01],
#        [1.08652635e+02, 4.86540767e+06, 4.97347931e+06, 6.10183877e+07,
#         5.47067222e+01],
#        [1.17843192e+02, 4.94017772e+06, 5.04796848e+06, 6.10183877e+07,
#         5.22002201e+01],
#        [1.06690274e+02, 4.87383966e+06, 4.98027516e+06, 6.10183877e+07,
#         5.54860067e+01],
#        [1.01641803e+02, 4.95268390e+06, 5.06017153e+06, 6.60922986e+07,
#         5.63147835e+01],
#        [9.99432248e+01, 4.87209745e+06, 4.97856004e+06, 6.60922986e+07,
#         5.30089022e+01],
#        [8.92907622e+01, 4.97018950e+06, 5.07916511e+06, 6.60922986e+07,
#         5.31457449e+01],
#        [1.03149342e+02, 5.38003692e+06, 5.49047815e+06, 6.65208523e+07,
#         5.25913931e+01],
#        [1.03143636e+02, 5.16221491e+06, 5.26400825e+06, 6.65208523e+07,
#         5.14496760e+01],
#        [1.06711028e+02, 5.38322981e+06, 5.49398079e+06, 6.65208523e+07,
#         5.18300365e+01],
#        [9.79782279e+01, 5.31247434e+06, 5.41884071e+06, 7.63903104e+07,
#         5.56129410e+01],
#        [1.04940055e+02, 5.38453139e+06, 5.49517778e+06, 7.63903104e+07,
#         5.81493395e+01],
#        [9.68477771e+01, 5.28174118e+06, 5.38710355e+06, 7.63903104e+07,
#         5.52056601e+01],
#        [1.01169866e+02, 5.38704502e+06, 5.49759578e+06, 7.50388876e+07,
#         5.38949773e+01],
#        [1.10360424e+02, 5.46181507e+06, 5.57208495e+06, 7.50388876e+07,
#         5.13884751e+01],
#        [9.92075049e+01, 5.39547701e+06, 5.50439163e+06, 7.50388876e+07,
#         5.46742617e+01],
#        [9.41590345e+01, 5.47432125e+06, 5.58428800e+06, 8.05225004e+07,
#         5.55030386e+01],
#        [9.24604561e+01, 5.39373480e+06, 5.50267650e+06, 8.05225004e+07,
#         5.21971573e+01],
#        [8.18079935e+01, 5.49182685e+06, 5.60328158e+06, 8.05225004e+07,
#         5.23340000e+01],
#        [9.56665735e+01, 5.90167427e+06, 6.01459462e+06, 8.09425956e+07,
#         5.17796482e+01],
#        [9.56608670e+01, 5.68385226e+06, 5.78812472e+06, 8.09425956e+07,
#         5.06379311e+01],
#        [9.92282594e+01, 5.90486716e+06, 6.01809726e+06, 8.09425956e+07,
#         5.10182915e+01],
#        [9.04954593e+01, 5.83411169e+06, 5.94295718e+06, 9.15728428e+07,
#         5.48011961e+01],
#        [9.74572864e+01, 5.90616874e+06, 6.01929425e+06, 9.15728428e+07,
#         5.73375946e+01],
#        [8.93650084e+01, 5.80337853e+06, 5.91122002e+06, 9.15728428e+07,
#         5.43939152e+01],
#        [9.36870975e+01, 5.90868237e+06, 6.02171225e+06, 9.00233915e+07,
#         5.30832324e+01],
#        [1.02877655e+02, 5.98345242e+06, 6.09620141e+06, 9.00233915e+07,
#         5.05767302e+01],
#        [9.17247362e+01, 5.91711436e+06, 6.02850810e+06, 9.00233915e+07,
#         5.38625168e+01],
#        [8.66762659e+01, 5.99595860e+06, 6.10840447e+06, 9.58540833e+07,
#         5.46912936e+01],
#        [8.49776875e+01, 5.91537215e+06, 6.02679297e+06, 9.58540833e+07,
#         5.13854123e+01],
#        [7.43252248e+01, 6.01346420e+06, 6.12739805e+06, 9.58540833e+07,
#         5.15222551e+01],
#        [8.81838048e+01, 6.42331162e+06, 6.53871108e+06, 9.62670128e+07,
#         5.09679032e+01]])

# %%
x = sm.add_constant(X_predicciones)

prediccion_DEMANDA_GUANTES = mvp.predict(x)

# %%
pred_results = mvp.get_prediction(x)

# %%
mvp.params
# Out:
# const                         -665430.326809
# EMAE Construccion                4068.769186
# Produccion Oil m3 Patagonia        -8.121423
# Produccion Oil m3 Argentina         7.884698
# PBI Valor Agregado                  0.026893
# Precio Brent                    -4689.929959
# dtype: float64

# %%
def get_regression(x):
    return -665430.326809 + 4068.769186 * x[0] - 8.121423 * x[1] + 7.884698 * x[2] + 0.026893 * x[3] - 4689.929959 * x[4]

# %%
X_predicciones.apply(get_regression, axis=1).plot()

# %% [markdown]
# # Ploteo ambas series

# %%
historico_DEMANDA_GUANTES = pd.read_excel('./Data para Proyecciones/Dataset_Proyecciones.xlsx')[['Año mes', 'Demanda de guantes']]
historico_DEMANDA_GUANTES.head()
# Out:
#      Año mes  Demanda de guantes
# 0 2015-01-01       275118.860759
# 1 2015-02-01       257997.421384
# 2 2015-03-01       255388.500000
# 3 2015-04-01       204928.248447
# 4 2015-05-01       236073.407407

# %%
X_predicciones.columns = ['EMAE Construccion', 'Produccion Oil m3 Patagonia',
                          'Produccion Oil m3 Argentina', 'PBI Valor Agregado', 'Precio Brent']

# %%
X_predicciones.merge(prediccion_df, left_index=True, right_index=True).to_excel('./MATRIZ_PROYECCION_DEMANDA_GUANTES_v1.xlsx')

# %%
prediccion_DEMANDA_GUANTES_df = prediccion_DEMANDA_GUANTES.to_frame().reset_index()
prediccion_DEMANDA_GUANTES_df.columns = ['Año mes', 'Demanda de guantes']

test = pd.concat([historico_DEMANDA_GUANTES, prediccion_DEMANDA_GUANTES_df], axis=0, ignore_index=False)
test.head()
# Out:
#      Año mes  Demanda de guantes
# 0 2015-01-01       275118.860759
# 1 2015-02-01       257997.421384
# 2 2015-03-01       255388.500000
# 3 2015-04-01       204928.248447
# 4 2015-05-01       236073.407407

# %%
test.to_excel('./PREDICCION_DEMANDA_GUANTES_V1.xlsx')

# %%
test.shape
# Out:
# (133, 2)

# %%
test.set_index('Año mes').plot(figsize=(10, 5))

# %% [markdown]
# # con objeto Prediction Results

# %%
pred_results.predicted_mean
# Out:
# array([ 150288.27114157,  157017.01321353,  227527.53743928,
#         295811.93507648,  328931.44001824,  292481.54795486,
#         328658.24655371,  357893.18448825,  302122.48741658,
#         357295.91638808,  376883.75635649,  329493.2213209 ,
#         315499.98835267,  304209.22943967,  335248.89274759,
#         443257.8228224 ,  476377.32776415,  439927.43570077,
#         465764.09552396,  494999.03345849,  439228.33638682,
#         512524.4577635 ,  532112.29773191,  484721.76269634,
#         470354.37565789,  459063.61674487,  490103.28005278,
#         631764.82953651,  664884.33447826,  628434.44241487,
#         645511.54313847,  674746.48107301,  618975.78400133,
#         707624.53592525,  727212.37589365,  679821.84085812,
#         665137.48937093,  653846.73045788,  684886.39376579,
#         855056.74432503,  888176.24926678,  851726.35720338,
#         861382.80145907,  890617.7393936 ,  834847.04232192,
#         936501.76816241,  956089.60813082,  908699.07309531,
#         893746.20532096,  882455.44640788,  913495.10971579,
#        1107816.67801196, 1140936.1829537 , 1104486.2908903 ,
#        1107856.32942752, 1137091.26736205, 1081320.57029037,
#        1193993.30096061, 1213581.140929  , 1166190.60589351,
#        1151010.26466982, 1139719.50575674, 1170759.16906464,
#        1385540.43037391, 1418659.93531565, 1382210.04325225,
#        1380254.55607244, 1409489.49400696, 1353718.79693528,
#        1475725.42533642, 1495313.26530482, 1447922.73026934,
#        1432549.68501753])

# %%
pred_results.conf_int()
# Out:
# array([[  68968.43037928,  231608.11190386],
#        [  91507.42406612,  222526.60236095],
#        [ 161915.09621236,  293139.9786662 ],
#        [ 229373.94689749,  362249.92325548],
#        [ 256003.23405332,  401859.64598316],
#        [ 224203.00194292,  360760.09396679],
#        [ 259509.67453515,  397806.81857227],
#        [ 279133.15083528,  436653.21814123],
#        [ 239164.46315526,  365080.5116779 ],
#        [ 264676.73802709,  449915.09474907],
#        [ 276094.25201364,  477673.26069933],
#        [ 243085.04148125,  415901.40116055],
#        [ 230466.81788485,  400533.15882049],
#        [ 218033.5273031 ,  390384.93157624],
#        [ 247328.13910538,  423169.64638979],
#        [ 293130.14845759,  593385.49718722],
#        [ 317638.56335594,  635116.09217236],
#        [ 288710.93368895,  591143.93771259],
#        [ 318641.29781835,  612886.89322957],
#        [ 339665.31477316,  650332.75214383],
#        [ 299790.32486517,  578666.34790847],
#        [ 327894.09008204,  697154.82544496],
#        [ 339223.07442842,  725001.52103539],
#        [ 313712.12309512,  655731.40229757],
#        [ 313335.22221792,  627373.52909787],
#        [ 293389.97459196,  624737.25889778],
#        [ 327429.49617412,  652777.06393143],
#        [ 368022.28931889,  895507.36975412],
#        [ 392241.49653326,  937527.17242326],
#        [ 363751.15979911,  893117.72503062],
#        [ 390627.62926995,  900395.457007  ],
#        [ 412309.45370314,  937183.50844288],
#        [ 372304.83013571,  865646.73786694],
#        [ 404289.43546313, 1010959.63638738],
#        [ 415243.45680555, 1039181.29498175],
#        [ 392800.85094338,  966842.83077286],
#        [ 397652.40422881,  932622.57451305],
#        [ 374409.00993674,  933284.45097902],
#        [ 410898.47736682,  958874.31016476],
#        [ 454268.91797617, 1255844.5706739 ],
#        [ 478513.65574886, 1297838.8427847 ],
#        [ 450014.69713531, 1253438.01727146],
#        [ 474557.09302229, 1248208.50989585],
#        [ 496571.7905176 , 1284663.68826959],
#        [ 456500.01604041, 1213194.06860343],
#        [ 492189.42337439, 1380814.11295044],
#        [ 502794.01087774, 1409385.20538389],
#        [ 481965.44394225, 1335432.70224836],
#        [ 489514.62906794, 1297977.78157398],
#        [ 464535.96024754, 1300374.93256823],
#        [ 502422.41220068, 1324567.80723091],
#        [ 550418.03234781, 1665215.32367611],
#        [ 574754.11963282, 1707118.24627458],
#        [ 546147.10309062, 1662825.47868998],
#        [ 568772.72511704, 1646939.933738  ],
#        [ 590977.92512745, 1683204.60959665],
#        [ 550874.77802088, 1611766.36255985],
#        [ 589850.86795508, 1798135.73396613],
#        [ 600169.41254265, 1826992.86931536],
#        [ 580325.09447257, 1752056.11731444],
#        [ 589505.87157738, 1712514.65776227],
#        [ 563455.28980186, 1715983.72171162],
#        [ 602241.8470018 , 1739276.49112748],
#        [ 655007.68783959, 2116073.17290822],
#        [ 679443.0255038 , 2157876.8451275 ],
#        [ 650711.90791697, 2113708.17858753],
#        [ 671730.84941615, 2088778.26272872],
#        [ 694055.91063889, 2124923.07737503],
#        [ 653938.24572518, 2053499.34814538],
#        [ 695763.24249652, 2255687.60817632],
#        [ 705852.26868036, 2284774.26192929],
#        [ 686665.77328212, 2209179.68725657],
#        [ 696937.2911836 , 2168162.07885146]])

# %%
test.set_index('Año mes', inplace=True)

# %%
prediccion = {
    'prediccion': pred_results.predicted_mean,
    'lower CI': [i[0] for i in pred_results.conf_int()],
    'upper CI': [i[1] for i in pred_results.conf_int()],
}

prediccion_df = pd.DataFrame(data=prediccion)

# %%
dr
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30', '2020-10-31', '2020-11-30', '2020-12-31',
#                '2021-01-31', '2021-02-28', '2021-03-31', '2021-04-30',
#                '2021-05-31', '2021-06-30', '2021-07-31', '2021-08-31',
#                '2021-09-30', '2021-10-31', '2021-11-30', '2021-12-31',
#                '2022-01-31', '2022-02-28', '2022-03-31', '2022-04-30',
#                '2022-05-31', '2022-06-30', '2022-07-31', '2022-08-31',
#                '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-31',
#                '2023-01-31', '2023-02-28', '2023-03-31', '2023-04-30',
#                '2023-05-31', '2023-06-30', '2023-07-31', '2023-08-31',
#                '2023-09-30', '2023-10-31', '2023-11-30', '2023-12-31',
#                '2024-01-31', '2024-02-29', '2024-03-31', '2024-04-30',
#                '2024-05-31', '2024-06-30', '2024-07-31', '2024-08-31',
#                '2024-09-30', '2024-10-31', '2024-11-30', '2024-12-31',
#                '2025-01-31', '2025-02-28', '2025-03-31', '2025-04-30',
#                '2025-05-31', '2025-06-30', '2025-07-31', '2025-08-31',
#                '2025-09-30', '2025-10-31', '2025-11-30', '2025-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
dr = pd.date_range(start='2020-01-01', end='2026-01-01', freq='MS')
prediccion_df['fecha'] = dr
prediccion_df.head()
# Out:
#       prediccion       lower CI       upper CI      fecha
# 0  150288.271142   68968.430379  231608.111904 2020-01-01
# 1  157017.013214   91507.424066  222526.602361 2020-02-01
# 2  227527.537439  161915.096212  293139.978666 2020-03-01
# 3  295811.935076  229373.946897  362249.923255 2020-04-01
# 4  328931.440018  256003.234053  401859.645983 2020-05-01

# %%
prediccion_df.to_excel('./PREDICCION_DEMANDA_GUANTES-CI.xlsx')

# %%
prediccion_df.set_index('fecha', inplace=True)

# %%
fig, ax = plt.subplots(1,1, figsize=(15, 6))
prediccion_df.plot( y='prediccion', ax=ax)
ax.fill_between(prediccion_df.index,
                y1=prediccion_df['lower CI'],
                y2=prediccion_df['upper CI'], alpha=0.3)

plt.grid(True, alpha=0.4)

# plt.xticks(prediccion_df.index, zip(prediccion_df.fecha.dt.year, prediccion_df.fecha.dt.month), rotation=90)
plt.xlabel('AÑO', fontsize=15)
plt.xticks(fontsize=15)
plt.tight_layout()
plt.savefig('./visuals/proyeccion_demanda_guantes.jpg')
